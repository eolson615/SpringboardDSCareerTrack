# %% [markdown]
# # Guided Capstone Step 3 Exploratory Data Analysis

# %% [markdown]
# This is the third step in the Data Science Method. We introduced this topic in the last subunit. With Data Wrangling out of the way we can progress to the Exploratory Data Analysis section. In this exercise, you will learn to build data profiles and plots, including relationship plot and data correlation plot. You will also implement k-means clustering, complete clusters, and update data frame as a CSV file. Let's get started!
#
# **The Data Science Method**
#
#
# 1.   Problem Identification
#
# 2.   Data Wrangling
#   * Data Collection
#    * Data Organization
#   * Data Definition
#   * Data Cleaning
#
# 3.   **Exploratory Data Analysis**
#  * Build data profile tables and plots
#         - Outliers & Anomalies
#  * Explore data relationships
#  * Identification and creation of features
#
# 4.   Pre-processing and Training Data Development
#   * Create dummy or indicator features for categorical variables
#   * Standardize the magnitude of numeric features
#   * Split into testing and training datasets
#   * Apply scaler to the testing set
# 5.   Modeling
#   * Fit Models with Training Data Set
#   * Review Model Outcomes — Iterate over additional models as needed.
#   * Identify the Final Model
#
# 6.   Documentation
#   * Review the Results
#   * Present and share your findings - storytelling
#   * Finalize Code
#   * Finalize Documentation

# %% [markdown]
# **<font color='teal'> Start by loading the necessary packages as we did in step 2 and printing out our current working directory just to confirm we are in the correct project directory. </font>**

# %%
#load python packages
import os
import pandas as pd
import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd /content/drive/My\ Drive/Colab\ Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# **<font color='teal'> If you need to change your path refer back to step 2 on how to do that. Then load the csv file you created in step 2, remember it should be saved inside your data subfolder and print the first five rows.</font>**

# %%
url_skidata_step2 = 'https://raw.githubusercontent.com/eolson615/SpringboardDSCareerTrack/master/Capstone_Project_1/Data/step2_output.csv'

sd_stp2 = pd.read_csv(url_skidata_step2, index_col=[0])
sd_stp2.head()
# Out:
#                   Name   Region  ... projectedDaysOpen  NightSkiing_ac
# 0       Alyeska Resort   Alaska  ...             150.0           550.0
# 1  Eaglecrest Ski Area   Alaska  ...              90.0             0.0
# 2     Hilltop Ski Area   Alaska  ...             152.0            30.0
# 3     Arizona Snowbowl  Arizona  ...             122.0             0.0
# 4  Sunrise Park Resort  Arizona  ...             104.0            80.0
#
# [5 rows x 27 columns]

# %% [markdown]
# # Build data profile tables and plots

# %% [markdown]
# **<font color='teal'> Print out the summary stats table transposed to fit on the screen using the `describe()` function.</font>**

# %%
sd_stp2.describe()
# Out:
#         summit_elev  vertical_drop  ...  projectedDaysOpen  NightSkiing_ac
# count    330.000000     330.000000  ...         330.000000      330.000000
# mean    4591.818182    1215.427273  ...         120.053004       56.890909
# std     3735.535934     947.864557  ...          28.742976       93.464882
# min      315.000000      60.000000  ...          30.000000        0.000000
# 25%     1403.750000     461.250000  ...         101.250000        0.000000
# 50%     3127.500000     964.500000  ...         120.053004       27.000000
# 75%     7806.000000    1800.000000  ...         136.000000       83.750000
# max    13487.000000    4425.000000  ...         305.000000      650.000000
#
# [8 rows x 24 columns]

# %% [markdown]
# **<font color='teal'> Histograms are an excellent way to review the range and density of values for each numeric features in your data set and build data profiles. Plot the histograms for all numeric features and adjust the bins size to 25.</font>**

# %%
hist = sd_stp2.hist(bins=25, figsize=(30,30))

# %% [markdown]
# Look for similarities in the features that may indicate that they are duplicates or highly correlated features. Make a note of your findings and any other interesting insights you find about these numeric features.

# %% [markdown]
# Notes on Histograms:
#
# -AdultWeekend and Adultweekday: look similar, but there is an adjustment in the weekend prices. It also seems that some place might have the same price.
#
# -summit_elev and base_elev have similar shapes
#
# -daysOpenLastYear and projectedDaysOpen have similar shapes.
#
# -It seems the total chair lifts
#
# possible outlier check: yearsOpen, SkiableTerrain_ac, Snow Making_ac

# %% [markdown]
# **<font color='teal'> Okay, now you should be getting a sense for what the data look like. Let's create a barplot for the categorical features `Region` and `state` where the heights of the bars are the counts of each level in that variable. </font>**

# %% [markdown]
# **<font color='teal'>State Levels Plot</font>**

# %%
# Uncomment the following code to get your visualization started 
f, ax = plt.subplots(figsize=(10, 10))

# In the following brackets, we want the value_counts() of the states 
x = pd.DataFrame(sd_stp2.state.value_counts())

# Get the state names by calling list() on the x.index
names = list(x.index)

# Get the values by plugging x.state into the list() function
values = list(x.state)

# We're now going to call the barplot() method on our sns seaborn object. 
# If you don't have a searborn object yet, make sure you've imported seaborn as sns in your imports above. 
sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# **<font color='teal'>Region Levels Plot</font>**

# %%
# Now do the same for regions! 
f, ax= plt.subplots(figsize=(10, 10))

x = pd.DataFrame(sd_stp2.Region.value_counts())

names = list(x.index)

values = list(x.Region)

sns.barplot(x=values, y=names, palette="RdBu_r")

# %% [markdown]
# By reviewing the State and Regions counts plots you should notice that the Region feature is nearly identical to the state and therfore we can remove from the dataframe.**<font color='teal'> Remove the `Region` column using the drop function.</font>**

# %%
sd_noRegion = sd_stp2.drop(columns=['Region'])
if 'Region' in sd_noRegion:
  print('in')

# %% [markdown]
# ## Anamolies & Outliers - Review boxplots

# %% [markdown]
# **<font color='teal'> Print boxplot for every column</font>**
#
# Hint: you'll see the methodology here in this article on Exploratory Data Analysis [here](nce-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
boxplot = sd_noRegion.boxplot(figsize=(7,5), vert=False, fontsize=10)

# %% [markdown]
# You need to create boxplots and  histograms to evaluate the data for potential outliers or data anomalies. Generally, outliers are defined as observations that differ significantly from the other values in the dataset or feature.
#
# Reviewing the distribution of values by column will help you  interpret this. Outliers are extreme values that fall far outside the mean and standard deviation of a set of observations. They  can mislead the training process in building machine learning models. Outliers may be real anomalies in the observations or artificial errors.
#
# One method for outlier analysis is extreme value analysis using a boxplot, which assumes a normal distribution. The figure below describes the components of a boxplot. Notice the outlier is the point outside the upper whisker end.
#
# ![](AnnotatedBoxplot.png)
# <font color='teal'>Follow these steps:
#
# 1. Create boxplots - earlier step
# 2. Apply outlier removal using the Interquartile range or replacement
# 3. Review how many observations were removed</font>
#
# Hint: Recall from your statistics prework that a common definition of an outlier is an observation lying more than (1.5 * the Interquartile range) above the third quartile, or more than just that much below the first quartile.

# %%
# Let's get the Interquartile range, or IQR. This is equal to Q3 - Q1. 
# First, let's use the quantile() method to get the first quartile, and store it in a variable called Q1.
# We'll want to plug 0.25 into the quantile method. 
Q1 = sd_noRegion.quantile(0.25)

# Now get Q3 and store in a variable called Q3. 
Q3 = sd_noRegion.quantile(.75)

# Now calculate the IQR, storing it in a variable called IQR.
IQR = Q3 - Q1

# Make a variable called `dfno`, and assign it the value: df[~((df < (Q1 - 1.5 * IQR)) |(df> (Q3 + 1.5 * IQR))).any(axis=1)]. 
# This filters on our existing dataframe, picking out just those observations that are NOT outliers. 
dfno = sd_noRegion[~((sd_noRegion < (Q1 - 1.5 * IQR)) | (sd_noRegion > (Q3 + 1.5 * IQR))).any(axis=1)]


# We now want to make a boxplot of this new dataframe dfno. 
boxplot2 = dfno.boxplot(grid=False, vert=False, fontsize=15, figsize=(12,15))

# %%
# Print the shapes of our dataframes df and dfno to compare the number of observations in each. 
print(sd_noRegion.shape)
print(dfno.shape)
# Out:
# (330, 26)
# (167, 26)

# %% [markdown]
# There are many ways to discover and remove outliers, and what counts as a sensible way of doing so depends on your problem, your methodology for solving that problem, and the nature of your data.
#
# Each method will have its merits and demerits. As we can see, in this instance, we've lost a great many observations!
#
# There is no hard and fast rule as to which outlier removal method is best in all cases, and you will have to exercise your good judgement in arriving at an appropriate method for your problem at hand. We will cover outlier removal in more depth in units 7 (Data Wrangling) and 10 (Statistics for Exploratory Data Analysis) of the course.

# %% [markdown]
# There are many possible response variables you could have identified in Step 1 of this guided capstone. However, for the rest of this guided capstone project, we will focus on increasing revenue by increasing the lift ticket prices and the number of days the resort is open per year. In this case, we need to investigate the expected lift ticket price for Big Mountain based on all the other given resort characteristics. In addition, we want to predict the number of days the resort will be open each season.

# %%
#I am making a different data set with just the rows of outliers for 3 columns being removed.
yearsOpen_outlier = sd_noRegion.iloc[sd_noRegion['yearsOpen'].argmax()]
yearsOpen_outlier
#it looks like this was the date the ski resort opened '2019', so this should be changes to '2'
# Out:
# Name                 Pine Knob Ski Resort
# state                            Michigan
# summit_elev                          1308
# vertical_drop                         300
# base_elev                            1009
# trams                                   0
# fastEight                               0
# fastSixes                               0
# fastQuads                               0
# quad                                    0
# triple                                  0
# double                                  0
# surface                                 6
# total_chairs                            6
# Runs                                   14
# TerrainParks                            3
# LongestRun_mi                           1
# SkiableTerrain_ac                      80
# Snow Making_ac                         80
# daysOpenLastYear                  115.104
# yearsOpen                            2019
# averageSnowfall                   185.316
# AdultWeekday                           49
# AdultWeekend                           57
# projectedDaysOpen                 120.053
# NightSkiing_ac                          0
# Name: 115, dtype: object

# %%
#this is to change the yearOpen outlier
sd_noRandnoYear = sd_noRegion.replace({'yearsOpen': 2019}, 2)
sd_noRandnoYear.iloc[115]
# Out:
# Name                 Pine Knob Ski Resort
# state                            Michigan
# summit_elev                          1308
# vertical_drop                         300
# base_elev                            1009
# trams                                   0
# fastEight                               0
# fastSixes                               0
# fastQuads                               0
# quad                                    0
# triple                                  0
# double                                  0
# surface                                 6
# total_chairs                            6
# Runs                                   14
# TerrainParks                            3
# LongestRun_mi                           1
# SkiableTerrain_ac                      80
# Snow Making_ac                         80
# daysOpenLastYear                  115.104
# yearsOpen                               2
# averageSnowfall                   185.316
# AdultWeekday                           49
# AdultWeekend                           57
# projectedDaysOpen                 120.053
# NightSkiing_ac                          0
# Name: 115, dtype: object

# %%
#this is to look at the skiable terrian outlier
skiableTerrain_ac_outlier = sd_noRandnoYear.iloc[sd_noRandnoYear['SkiableTerrain_ac'].argmax()]
skiableTerrain_ac_outlier
# Out:
# Name                 Silverton Mountain
# state                          Colorado
# summit_elev                       13487
# vertical_drop                      3087
# base_elev                         10400
# trams                                 0
# fastEight                             0
# fastSixes                             0
# fastQuads                             0
# quad                                  0
# triple                                0
# double                                1
# surface                               0
# total_chairs                          1
# Runs                            48.2147
# TerrainParks                    2.82079
# LongestRun_mi                       1.5
# SkiableTerrain_ac                 26819
# Snow Making_ac                  174.873
# daysOpenLastYear                    175
# yearsOpen                            17
# averageSnowfall                     400
# AdultWeekday                         79
# AdultWeekend                         79
# projectedDaysOpen                   181
# NightSkiing_ac                        0
# Name: 39, dtype: object

# %%
#Upon further review, Silverton Mountain (through research) would be a good canidate to drop as does not operate as a normal ski resort
sd_noRnoYnoTer = sd_noRandnoYear.drop([39])
sd_noRnoYnoTer.iloc[39]
# Out:
# Name                   Cooper
# state                Colorado
# summit_elev             11700
# vertical_drop            1200
# base_elev               10500
# trams                       0
# fastEight                   0
# fastSixes                   0
# fastQuads                   0
# quad                        0
# triple                      1
# double                      1
# surface                     2
# total_chairs                4
# Runs                       41
# TerrainParks                1
# LongestRun_mi               1
# SkiableTerrain_ac         400
# Snow Making_ac        174.873
# daysOpenLastYear          130
# yearsOpen                  74
# averageSnowfall           260
# AdultWeekday               56
# AdultWeekend               56
# projectedDaysOpen         130
# NightSkiing_ac              0
# Name: 40, dtype: object

# %%
#looking at the Snow Making_ac outlier
SnowMaking_ac_outlier = sd_noRnoYnoTer.iloc[sd_noRnoYnoTer['Snow Making_ac'].argmax()]
SnowMaking_ac_outlier
# Out:
# Name                 Heavenly Mountain Resort
# state                              California
# summit_elev                             10067
# vertical_drop                            3500
# base_elev                                7170
# trams                                       2
# fastEight                                   0
# fastSixes                                   2
# fastQuads                                   7
# quad                                        1
# triple                                      5
# double                                      3
# surface                                     8
# total_chairs                               28
# Runs                                       97
# TerrainParks                                3
# LongestRun_mi                             5.5
# SkiableTerrain_ac                        4800
# Snow Making_ac                           3379
# daysOpenLastYear                          155
# yearsOpen                                  64
# averageSnowfall                           360
# AdultWeekday                           57.917
# AdultWeekend                          64.1668
# projectedDaysOpen                         157
# NightSkiing_ac                              0
# Name: 11, dtype: object

# %% [markdown]
# ###This is actaully a good piece of data except for their snow Making capabilities, which looks to actually be true (they claim to cover close to 80% of their skiable terrain with made snow if needed). I will drop it, but I am hesitant to do so.

# %%
sd_noRegDropOut = sd_noRnoYnoTer.drop([11])
sd_noRegDropOut.iloc[11]
# Out:
# Name                 June Mountain
# state                   California
# summit_elev                  10090
# vertical_drop                 2590
# base_elev                     7545
# trams                            0
# fastEight                        0
# fastSixes                        0
# fastQuads                        2
# quad                             0
# triple                           0
# double                           4
# surface                          1
# total_chairs                     7
# Runs                            41
# TerrainParks                     2
# LongestRun_mi                    2
# SkiableTerrain_ac             1500
# Snow Making_ac             174.873
# daysOpenLastYear           115.104
# yearsOpen                       58
# averageSnowfall                250
# AdultWeekday                57.917
# AdultWeekend               64.1668
# projectedDaysOpen              128
# NightSkiing_ac                   0
# Name: 12, dtype: object

# %%
type(sd_noRegDropOut)
# Out:
# pandas.core.frame.DataFrame

# %%
bigmountianprofile = sd_noRnoYnoTer.loc[sd_noRnoYnoTer.Name == 'Whitefish Mountain Resort']
bigmountianprofile
# Out:
#                           Name    state  ...  projectedDaysOpen  NightSkiing_ac
# 151  Whitefish Mountain Resort  Montana  ...              123.0           600.0
#
# [1 rows x 26 columns]

# %% [markdown]
# <font color='teal'>**Review the `AdultWeekday`,`AdultWeekend` response variable distributions**</font>

# %%
# Make a histogram of the 'AdultWeekday' column of the dfno dataframe. 
# You'll want to call hist() on that column 
hist = dfno.hist(column='AdultWeekday', bins=25)

# %%
# Do the same but with the AdultWeekend column 
hist = dfno.hist(column='AdultWeekend', bins=25)

# %%
#same for my more robust data set
hist = sd_noRegDropOut.hist(column='AdultWeekday', bins=25)

# %%
hist = sd_noRegDropOut.hist(column='AdultWeekend', bins=25)

# %% [markdown]
# <font color='teal'>**Review the `daysOpenLastYear`,`projecteDaysOpen` response variable distributions**</font>

# %%
# Do the same as above! You got this :) 
hist = dfno.hist(column='daysOpenLastYear', bins=25)

# %%
hist = dfno.hist(column='projectedDaysOpen', bins=25)

# %%
hist = sd_noRegDropOut.hist(column='daysOpenLastYear', bins=25)

# %%
hist = sd_noRegDropOut.hist(column='projectedDaysOpen', bins=25)

# %% [markdown]
# After reviewing these respons varible distributions, there doesn't appear to be any data issues to mitigate. Now, we move on to investigating feature relationship and interactions between the features the response.

# %% [markdown]
# # Explore data relationships

# %% [markdown]
# <font color='teal'>**Create pairplots or what is commonly referred to as biplots**</font>
#
# Hint: pairplots are covered in this article on EDA [here](https://medium.com/@aiden.dataminer/the-data-science-method-dsm-exploratory-data-analysis-bc84d4d8d3f9).

# %%
g = sns.pairplot(dfno)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Identification and creation of features

# %% [markdown]
# <font color='teal'>**Create a Pearson correlation heatmap**</font>

# %%
#Calculate the correlation coefficients
corr = dfno.corr(method='pearson')
#plot it in the next line
corr.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/style.py:1089: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(s.to_numpy()) if vmin is None else vmin
# /usr/local/lib/python3.6/dist-packages/pandas/io/formats/style.py:1090: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
#     #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col1 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col2 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col6 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col7 {
#             background-color:  #688aef;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col8 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col9 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col10 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col11 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col12 {
#             background-color:  #f2cab5;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col13 {
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col14 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col15 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col16 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col17 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col18 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col19 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col20 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col21 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col22 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row0_col23 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col0 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col2 {
#             background-color:  #f6bea4;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col6 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col7 {
#             background-color:  #6b8df0;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col8 {
#             background-color:  #96b7ff;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col9 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col10 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col11 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col12 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col13 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col14 {
#             background-color:  #f7b89c;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col15 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col16 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col17 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col18 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col19 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col20 {
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col21 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col22 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row1_col23 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col0 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col1 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col6 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col7 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col8 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col9 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col10 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_b9c5c620_a95e_11ea_8a5f_0242ac1c0002row2_col11 {
#             background-color:  #3b4cc0;

# %%
corr2 = sd_noRegDropOut.corr(method='pearson')
corr2.round(2).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col1 {
#             background-color:  #f49a7b;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col2 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col3 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col4 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col5 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col6 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col7 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col8 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col9 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col10 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col11 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col12 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col13 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col14 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col15 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col16 {
#             background-color:  #adc9fd;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col17 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col18 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col19 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col20 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col21 {
#             background-color:  #bad0f8;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col22 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row0_col23 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col0 {
#             background-color:  #f29274;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col2 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col3 {
#             background-color:  #f4c6af;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col4 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col5 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col6 {
#             background-color:  #f7b396;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col7 {
#             background-color:  #89acfd;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col8 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col9 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col10 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col11 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col12 {
#             background-color:  #ec8165;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col13 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col14 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col15 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col16 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col17 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col18 {
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col19 {
#             background-color:  #f7af91;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col20 {
#             background-color:  #f5c0a7;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col21 {
#             background-color:  #f1cdba;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col22 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row1_col23 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col0 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col1 {
#             background-color:  #f2c9b4;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col3 {
#             background-color:  #9ebeff;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col4 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col5 {
#             background-color:  #90b2fe;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col6 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col7 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col8 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col9 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col10 {
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }    #T_8ef9f876_a963_11ea_8a5f_0242ac1c0002row2_col11 {
#             background-color:  #6180e9;

# %% [markdown]
# When reviewing the Pearson correlation coefficient heatmap, you can see substantial differences in the correlations compared to the response variable(s) as well as in the features when compared to each other. The heatmap helps identify features that suffer from multi-collinearity.

# %% [markdown]
# <font color='teal'>**Use the correlation matrix displayed in the heatmap to select and remove collinear features. Remember to exclude the response variable(s) from the matrix to ensure they are retained in your final model development dataset. Then select those features that are more than 95% correlated for removal.**</font>
#
# Step 1: Create a correlation matrix that excludes your response variables.
#
# Step 2: Select the upper triangle of the correlation matrix. This is because a correlation matrix actually contains the same information, twice over!
#
# Step 3: Find the index of feature columns with a correlation greater than 0.95.

# %%
# Step 1. Call the variable corr_matrix
corr_matrix = dfno.drop(['AdultWeekday','AdultWeekend','daysOpenLastYear','projectedDaysOpen'], axis=1).corr().abs()

# Step 2. Uncomment the following code to get the upper triangle of the correlation matrix 
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Step 3. This code iterates through our columns and gets the index of any that have a correlation > 0.95
# Call the variable to_drop, get the columns of our 'upper' variable, make sure the threshold is 0.95.
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
# Let's see those features! 
print('Features selected to drop include:',to_drop)
# Out:
# Features selected to drop include: ['base_elev']

# %%
print('Reduced dataframe size: ',dfno.drop(dfno[to_drop], axis=1).shape)
# Out:
# Reduced dataframe size:  (167, 25)

# %%
# Now replace dfno by the result of dropping the columns in the to_drop variable from it
dfno = dfno.drop(to_drop, axis=1)
dfno.shape
# Out:
# (167, 25)

# %% [markdown]
# Now we address the feature creation piece of this step. We can create additional features through many methods such as: combining several features, grouping features into bins, or even by applying an unsupervised classification algorithm, such as k-means clustering and using the clusters as features in our model development dataset.
#
# Clustering essentially finds patterns in data when we don't know in advance what we're looking for. The K-means algorithm is one way of doing clustering. It puts our data into groups (or 'clusters') which can then become features for further analysis. What the k-means algorithm outputs, though, depends on the number of clusters we set out to have. We will use a method called 'Elbow plotting' to determine this number.
#
# We will cover clustering and k-means thoroughly in the Unsupervised Learning unit of this course, but for now, we'll use it for feature creation alone, which is an integral part of Exploratory Data Analysis. Don't worry if you don't understand the details just yet.

# %% [markdown]
# Run the next two cells below to create an Elbow plot. The Elbow plot is a diagnostic tool that helps us determine the number of clusters to include in our k-means clustering implementation.
#
# In this example, the error between clusters and within clusters is compared for a range of 1 to 11 clusters, and it appears the elbow is between two and four, therefore we set the parameter k = 3.

# %%
from sklearn.cluster import KMeans
x = dfno.drop(['Name','state'], axis =1).values

# %%
Error =[]
for i in range(1, 11):
  kmeans = KMeans(n_clusters = i).fit(x)
  kmeans.fit(x)
  Error.append(kmeans.inertia_)
import matplotlib.pyplot as plt
plt.plot(range(1, 11), Error)
plt.title('Elbow method')
plt.xlabel('No of clusters')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# <font color='teal'>**Fit the kmeans algorithm with the k parameter set to three and plot the results.**</font>

# %%
# This code will fit the k-means algorithm with our k parameter set to three, and plot the results. Cool, huh? 
kmeans3 = KMeans(n_clusters=3)
y_kmeans3 = kmeans3.fit_predict(x)
plt.scatter(x[:, 0], x[:, 1], c=y_kmeans3, s=50, cmap='viridis')

centers = kmeans3.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %% [markdown]
# <font color='teal'>**Add the clusters to your dataframe as a new column to include in the next step and write the updated dataframe out as csv. Save the dataframe in the data folder and name it `step3_output.csv`.**</font>

# %%
# Make a new column in your dfno dataframe called 'clusters', and assign it the variable: y_kmeans3
dfno['clusters'] = y_kmeans3

# %%
dfno.shape
# Out:
# (167, 26)

# %%
# Write your dataframe to csv 
dfno.to_csv('step3_output.csv')

from google.colab import files
files.download('step3_output.csv')
